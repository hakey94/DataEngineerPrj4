# %%
path = "/FileStore/tables/riders.csv"
df_riders = spark.read \
    .option("inferSchema", "true") \
    .option("header", "false") \
    .option("sep", ",") \
    .format("csv") \
    .load(path) \
    .withColumnRenamed("_c0","RiderId") \
    .withColumnRenamed("_c1","FirstName")\
    .withColumnRenamed("_c2","LastName")\
    .withColumnRenamed("_c3","Address")\
    .withColumnRenamed("_c4","BirthDay")\
    .withColumnRenamed("_c5","StartDate")\
    .withColumnRenamed("_c6","EndDate")\
    .withColumnRenamed("_c7","IsMember")

# %%
df_riders.write \
  .format("delta") \
  .mode("overwrite") \
  .save("/delta/riders")

# %%
path = "/FileStore/tables/payments.csv"
df_payments = spark.read \
    .option("inferSchema", "false") \
    .option("header", "false") \
    .format("csv") \
    .option("sep", ",") \
    .load(path) \
    .withColumnRenamed("_c0","PaymentId") \
    .withColumnRenamed("_c1","Date")\
    .withColumnRenamed("_c2","Amount")\
    .withColumnRenamed("_c3","RiderId")

# %%
df_payments.write \
  .format("delta") \
  .mode("overwrite") \
  .save("/delta/payments")

# %%
path = "/FileStore/tables/stations.csv"
df_stations = spark.read \
    .option("inferSchema", "false") \
    .option("header", "false") \
    .format("csv") \
    .option("sep", ",") \
    .load(path) \
    .withColumnRenamed("_c0","StationId") \
    .withColumnRenamed("_c1","Name")\
    .withColumnRenamed("_c2","Latitude")\
    .withColumnRenamed("_c3","Longitude")

# %%
df_stations.write \
  .format("delta") \
  .mode("overwrite") \
  .save("/delta/stations")

# %%
path = "/FileStore/tables/trips.csv"
df_trips = spark.read \
    .option("inferSchema", "false") \
    .option("header", "false") \
    .format("csv") \
    .option("sep", ",") \
    .load(path) \
    .withColumnRenamed("_c0","TripId") \
    .withColumnRenamed("_c1","Type")\
    .withColumnRenamed("_c2","StartTimeId")\
    .withColumnRenamed("_c3","EndTimeId")\
    .withColumnRenamed("_c4","StartStationId")\
    .withColumnRenamed("_c5","EndStationId")\
    .withColumnRenamed("_c6","RiderId")

# %%
df_trips.write \
  .format("delta") \
  .mode("overwrite") \
  .save("/delta/trips")
